# %% [markdown]
# # Simple Moving Average Trading Strategy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
apple = pd.read_csv("AAPl.csv")
apple = apple.set_index(pd.DatetimeIndex(apple['Date'].values))
apple
# Out:
#                   Date        Open        High         Low       Close  \
# 2009-03-27  2009-03-27    3.865357    3.876071    3.800000    3.816071
# 2009-03-30  2009-03-30    3.732500    3.750357    3.664643    3.731786
# 2009-03-31  2009-03-31    3.766071    3.837500    3.750000    3.754286
# 2009-04-01  2009-04-01    3.717500    3.892857    3.710357    3.881786
# 2009-04-02  2009-04-02    3.933571    4.098214    3.920714    4.025357
# ...                ...         ...         ...         ...         ...
# 2023-03-20  2023-03-20  155.070007  157.820007  154.149994  157.399994
# 2023-03-21  2023-03-21  157.320007  159.399994  156.539993  159.279999
# 2023-03-22  2023-03-22  159.300003  162.139999  157.809998  157.830002
# 2023-03-23  2023-03-23  158.830002  161.550003  157.679993  158.929993
# 2023-03-24  2023-03-24  158.860001  160.339996  157.850006  160.250000
#
#              Adj Close     Volume
# 2009-03-27    3.247928  492872800
# 2009-03-30    3.176192  502796000
# 2009-03-31    3.195342  570080000
# 2009-04-01    3.303859  589372000
# 2009-04-02    3.426055  812366800
# ...                ...        ...
# 2023-03-20  157.399994   73641400
# 2023-03-21  159.279999   73938300
# 2023-03-22  157.830002   75701800
# 2023-03-23  158.929993   67622100
# 2023-03-24  160.250000   59196500
#
# [3523 rows x 7 columns]

# %%
plt.figure(figsize=(16,8))
plt.title('Apple closing Price')
plt.plot(apple['Close'])
plt.xlabel('Date')
plt.ylabel('Close Price in USD')
plt.show()

# %%
def SMA(data, period = 30, column='Close'):
    return data[column].rolling(window=period).mean()

# %%
apple['SMA30'] = SMA(apple)
apple
# Out:
#                   Date        Open        High         Low       Close  \
# 2009-03-27  2009-03-27    3.865357    3.876071    3.800000    3.816071
# 2009-03-30  2009-03-30    3.732500    3.750357    3.664643    3.731786
# 2009-03-31  2009-03-31    3.766071    3.837500    3.750000    3.754286
# 2009-04-01  2009-04-01    3.717500    3.892857    3.710357    3.881786
# 2009-04-02  2009-04-02    3.933571    4.098214    3.920714    4.025357
# ...                ...         ...         ...         ...         ...
# 2023-03-20  2023-03-20  155.070007  157.820007  154.149994  157.399994
# 2023-03-21  2023-03-21  157.320007  159.399994  156.539993  159.279999
# 2023-03-22  2023-03-22  159.300003  162.139999  157.809998  157.830002
# 2023-03-23  2023-03-23  158.830002  161.550003  157.679993  158.929993
# 2023-03-24  2023-03-24  158.860001  160.339996  157.850006  160.250000
#
#              Adj Close     Volume       SMA30
# 2009-03-27    3.247928  492872800         NaN
# 2009-03-30    3.176192  502796000         NaN
# 2009-03-31    3.195342  570080000         NaN
# 2009-04-01    3.303859  589372000         NaN
# 2009-04-02    3.426055  812366800         NaN
# ...                ...        ...         ...
# 2023-03-20  157.399994   73641400  151.386333
# 2023-03-21  159.279999   73938300  151.638000
# 2023-03-22  157.830002   75701800  151.744000
# 2023-03-23  158.929993   67622100  151.977667
# 2023-03-24  160.250000   59196500  152.290334
#
# [3523 rows x 8 columns]

# %%
def strategy(df):
    buy, sell = [], []
    flag = 0
    buy_price = 0
    for i in range(0,len(df)):
        
        if df['SMA30'][i] > df['Close'][i] and flag == 0:
            buy.append(df['Close'][i])
            sell.append(np.nan)
            buy_price = df['Close'][i]
            flag = 1
            
        elif df['SMA30'][i] < df['Close'][i] and flag == 1 and buy_price < df['Close'][i]:
            sell.append(df['Close'][i])
            buy.append(np.nan)
            buy_price = 0
            flag = 0
            
        else:
            sell.append(np.nan)
            buy.append(np.nan)
            
    return(buy, sell)

# %%
strat = strategy(apple)
apple['Buy'] = strat[0]
apple['Sell'] = strat[1]

# %%
plt.figure(figsize=(16,8))
plt.title('Apple closing price with Buy & Sell signals')
plt.plot(apple['Close'], alpha = 0.5, label = 'Close')
plt.plot(apple['SMA30'], alpha = 0.5, label = 'SMA30')
plt.scatter(apple.index, apple['Buy'], color='green', label = 'Buy Signal', marker = '^', alpha = 1)
plt.scatter(apple.index, apple['Sell'], color='red', label = 'Sell Signal', marker = 'v', alpha = 1)
plt.xlabel('Date')
plt.ylabel('Closing price in USD')
plt.show()

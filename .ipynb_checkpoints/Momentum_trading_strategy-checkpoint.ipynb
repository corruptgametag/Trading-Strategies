# %% [markdown]
# # Momentum Trading Strategy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf

# %%
gld = yf.download('GLD', start='2016-01-01')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
day = np.arange(1,len(gld)+1)
gld['Day'] = day
gld.head()
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2016-01-04 00:00:00-05:00  103.129997  103.669998  102.489998  102.889999
# 2016-01-05 00:00:00-05:00  103.129997  103.459999  102.930000  103.180000
# 2016-01-06 00:00:00-05:00  104.370003  104.800003  103.930000  104.669998
# 2016-01-07 00:00:00-05:00  105.830002  106.239998  105.190002  106.150002
# 2016-01-08 00:00:00-05:00  105.480003  105.800003  105.040001  105.680000
#
#                             Adj Close    Volume  Day
# Date
# 2016-01-04 00:00:00-05:00  102.889999   6440000    1
# 2016-01-05 00:00:00-05:00  103.180000   3500300    2
# 2016-01-06 00:00:00-05:00  104.669998   9316600    3
# 2016-01-07 00:00:00-05:00  106.150002  11730400    4
# 2016-01-08 00:00:00-05:00  105.680000   7678200    5

# %%
gld = gld[['Day', 'High', 'Low','Open', 'Close']]
gld.head()
# Out:
#                            Day        High         Low        Open       Close
# Date
# 2016-01-04 00:00:00-05:00    1  103.669998  102.489998  103.129997  102.889999
# 2016-01-05 00:00:00-05:00    2  103.459999  102.930000  103.129997  103.180000
# 2016-01-06 00:00:00-05:00    3  104.800003  103.930000  104.370003  104.669998
# 2016-01-07 00:00:00-05:00    4  106.239998  105.190002  105.830002  106.150002
# 2016-01-08 00:00:00-05:00    5  105.800003  105.040001  105.480003  105.680000

# %%
gld.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1821 entries, 2016-01-04 00:00:00-05:00 to 2023-03-28 00:00:00-04:00
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Day     1821 non-null   int64
#  1   High    1821 non-null   float64
#  2   Low     1821 non-null   float64
#  3   Open    1821 non-null   float64
#  4   Close   1821 non-null   float64
# dtypes: float64(4), int64(1)
# memory usage: 85.4 KB

# %%
gld['9-day'] = gld['Close'].rolling(9).mean().shift()
gld['21-day'] = gld['Close'].rolling(21).mean().shift()
# Out:
# <ipython-input-16-48840fb7f3dc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['9-day'] = gld['Close'].rolling(9).mean().shift()
# <ipython-input-16-48840fb7f3dc>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['21-day'] = gld['Close'].rolling(21).mean().shift()

# %%
gld['signal'] = np.where(gld['9-day']>gld['21-day'],1,0)
gld['signal'] = np.where(gld['9-day']<gld['21-day'],-1,gld['signal'])
gld.dropna(inplace = True)
# Out:
# <ipython-input-20-c62202398298>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['signal'] = np.where(gld['9-day']>gld['21-day'],1,0)
# <ipython-input-20-c62202398298>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['signal'] = np.where(gld['9-day']<gld['21-day'],-1,gld['signal'])
# <ipython-input-20-c62202398298>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld.dropna(inplace = True)

# %%
gld['return'] = np.log(gld['Close']).diff()
gld['system_return'] = gld['signal'] * gld['return']
gld['entry'] = gld.signal.diff()
gld.head()
# Out:
# <ipython-input-38-86a2a5555375>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['return'] = np.log(gld['Close']).diff()
# <ipython-input-38-86a2a5555375>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['system_return'] = gld['signal'] * gld['return']
# <ipython-input-38-86a2a5555375>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gld['entry'] = gld.signal.diff()
#                            Day        High         Low        Open  \
# Date
# 2016-02-03 00:00:00-05:00   22  109.580002  107.900002  107.910004
# 2016-02-04 00:00:00-05:00   23  110.699997  109.919998  110.449997
# 2016-02-05 00:00:00-05:00   24  112.349998  109.580002  109.790001
# 2016-02-08 00:00:00-05:00   25  114.870003  113.389999  113.669998
# 2016-02-09 00:00:00-05:00   26  114.690002  113.550003  114.430000
#
#                                 Close       9-day      21-day  signal  \
# Date
# 2016-02-03 00:00:00-05:00  109.250000  106.797778  105.422381       1
# 2016-02-04 00:00:00-05:00  110.570000  107.215556  105.725238       1
# 2016-02-05 00:00:00-05:00  112.320000  107.834445  106.077143       1
# 2016-02-08 00:00:00-05:00  113.830002  108.527778  106.441429       1
# 2016-02-09 00:00:00-05:00  113.580002  109.254445  106.807143       1
#
#                              return  system_return       Cum_PnL  entry
# Date
# 2016-02-03 00:00:00-05:00       NaN            NaN           NaN    NaN
# 2016-02-04 00:00:00-05:00  0.012010       0.012010  1.200997e-02    0.0
# 2016-02-05 00:00:00-05:00  0.015703       0.015703  1.885942e-04    0.0
# 2016-02-08 00:00:00-05:00  0.013354       0.013354  2.518521e-06    0.0
# 2016-02-09 00:00:00-05:00 -0.002199      -0.002199 -5.537405e-09    0.0

# %%
plt.rcParams['figure.figsize'] = 12, 6
plt.grid(True, alpha = .3)
plt.plot(gld.iloc[-252:]['Close'], label = 'GLD')
plt.plot(gld.iloc[-252:]['9-day'], label = '9-day')
plt.plot(gld.iloc[-252:]['21-day'], label = '21-day')
plt.plot(gld[-252:].loc[gld.entry == 2].index, gld[-252:]['9-day'][gld.entry == 2], '^',
         color = 'g', markersize = 12)
plt.plot(gld[-252:].loc[gld.entry == -2].index, gld[-252:]['21-day'][gld.entry == -2], 'v',
         color = 'r', markersize = 12)
plt.legend(loc=2);

# %%
plt.plot(np.exp(gld['return']).cumprod(), label='Buy/Hold')
plt.plot(np.exp(gld['system_return']).cumprod(), label='System')
plt.legend(loc=2)
plt.grid(True, alpha=.3)
